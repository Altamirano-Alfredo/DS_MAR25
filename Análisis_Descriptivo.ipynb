# %% [markdown]
# <a href="https://colab.research.google.com/github/Altamirano-Alfredo/DS_MAR25/blob/main/An%C3%A1lisis_Descriptivo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#matplotlib inline
# Definir datos de dibujo
x = [1, 2, 3, 4, 5, 6, 7, 8]
y_bar = [5, 9, 19, 32, 28, 15, 8, 4]
y_line = [2, 9, 5, 7, 8, 9, 8, 10, 6, 7]
sns.set(context='poster',
        style='white',
        palette='dark',
        font='sans-serif',
        font_scale=0.55, color_codes='r', rc=None)
plt.bar(x, y_line)
plt.xlabel('Límite de clase')
plt.ylabel('Volumen')
plt.title('Total de productos que han experimentado variaciones')
plt.legend()
# Out:
# /tmp/ipython-input-1143292365.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#matplotlib inline
# Definir datos de dibujo
x = [1, 2, 3, 4, 5, 6, 7, 8]
y_bar = [5, 9, 19, 32, 28, 15, 8, 4]
#y_line = [2, 9, 5, 7, 8, 9, 8, 10, 6, 7]
sns.set(context='poster',
        style='white',
        palette='dark',
        font='sans-serif',
        font_scale=0.55, color_codes='r', rc=None)
sns.kdeplot(y_bar, shade = True , color = "Green")
plt.xlabel('Límite de clase')
plt.ylabel('Volumen')
plt.title('Total de productos que han experimentado variaciones')
plt.legend()
# Out:
# /tmp/ipython-input-3484265091.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(y_bar, shade = True , color = "Green")
# /tmp/ipython-input-3484265091.py:17: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
